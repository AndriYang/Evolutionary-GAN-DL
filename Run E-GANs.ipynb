# %%
# !pip install -r requirements.txt
# Out:
# Collecting torch>=0.4.0
#   Downloading torch-1.4.0-cp36-cp36m-manylinux1_x86_64.whl (753.4 MB)
#      |################################| 753.4 MB 24 kB/s s eta 0:00:011  |##                              | 54.2 MB 9.6 MB/s eta 0:01:13
# Collecting torchvision>=0.2.1
#   Downloading torchvision-0.5.0-cp36-cp36m-manylinux1_x86_64.whl (4.0 MB)
#      |################################| 4.0 MB 90.6 MB/s eta 0:00:01
# Collecting dominate>=2.3.1
#   Downloading dominate-2.5.1-py2.py3-none-any.whl (29 kB)
# Collecting visdom>=0.1.8.3
#   Downloading visdom-0.1.8.9.tar.gz (676 kB)
#      |################################| 676 kB 64.0 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 5)) (1.18.2)
# Requirement already satisfied: h5py>=2.7.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 6)) (2.10.0)
# Collecting pillow>=3.1.1
#   Downloading Pillow-7.1.1-cp36-cp36m-manylinux1_x86_64.whl (2.1 MB)
#      |################################| 2.1 MB 29.5 MB/s eta 0:00:01
# Collecting tqdm>=4.31.1
#   Downloading tqdm-4.45.0-py2.py3-none-any.whl (60 kB)
#      |################################| 60 kB 20.0 MB/s  eta 0:00:01
# Collecting scipy==1.1.0
#   Downloading scipy-1.1.0-cp36-cp36m-manylinux1_x86_64.whl (31.2 MB)
#      |################################| 31.2 MB 23.9 MB/s eta 0:00:01
# Collecting tensorflow-gpu==1.15
#   Downloading tensorflow_gpu-1.15.0-cp36-cp36m-manylinux2010_x86_64.whl (411.5 MB)
#      |################################| 411.5 MB 20 kB/s /s eta 0:00:01   |##                              | 26.4 MB 33.6 MB/s eta 0:00:12
# Collecting matplotlib
#   Downloading matplotlib-3.2.1-cp36-cp36m-manylinux1_x86_64.whl (12.4 MB)
#      |################################| 12.4 MB 126.3 MB/s eta 0:00:01
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision>=0.2.1->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from visdom>=0.1.8.3->-r requirements.txt (line 4)) (2.23.0)
# Requirement already satisfied: tornado in /usr/local/lib/python3.6/dist-packages (from visdom>=0.1.8.3->-r requirements.txt (line 4)) (6.0.4)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.6/dist-packages (from visdom>=0.1.8.3->-r requirements.txt (line 4)) (19.0.0)
# Collecting jsonpatch
#   Downloading jsonpatch-1.25-py2.py3-none-any.whl (11 kB)
# Collecting torchfile
#   Downloading torchfile-0.1.0.tar.gz (5.2 kB)
# Collecting websocket-client
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
#      |################################| 200 kB 109.7 MB/s eta 0:00:01
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15->-r requirements.txt (line 10)) (3.2.0)
# Collecting tensorflow-estimator==1.15.1
#   Downloading tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503 kB)
#      |################################| 503 kB 36.8 MB/s eta 0:00:01
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading tensorboard-1.15.0-py3-none-any.whl (3.8 MB)
#      |################################| 3.8 MB 101.6 MB/s eta 0:00:01
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15->-r requirements.txt (line 10)) (1.27.2)
# Collecting keras-applications>=1.0.8
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |################################| 50 kB 12.7 MB/s eta 0:00:01
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15->-r requirements.txt (line 10)) (1.12.1)
# Collecting gast==0.2.2
#   Downloading gast-0.2.2.tar.gz (10 kB)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15->-r requirements.txt (line 10)) (3.11.3)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15->-r requirements.txt (line 10)) (0.9.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15->-r requirements.txt (line 10)) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15->-r requirements.txt (line 10)) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/lib/python3/dist-packages (from tensorflow-gpu==1.15->-r requirements.txt (line 10)) (0.30.0)
# Collecting astor>=0.6.0
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15->-r requirements.txt (line 10)) (1.1.0)
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.2.0-cp36-cp36m-manylinux1_x86_64.whl (88 kB)
#      |################################| 88 kB 15.3 MB/s  eta 0:00:01
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      |################################| 67 kB 15.9 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->-r requirements.txt (line 11)) (2.8.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/lib/python3/dist-packages (from requests->visdom>=0.1.8.3->-r requirements.txt (line 4)) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->visdom>=0.1.8.3->-r requirements.txt (line 4)) (2019.11.28)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->visdom>=0.1.8.3->-r requirements.txt (line 4)) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->visdom>=0.1.8.3->-r requirements.txt (line 4)) (1.25.8)
# Collecting jsonpointer>=1.9
#   Downloading jsonpointer-2.0-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15->-r requirements.txt (line 10)) (3.2.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15->-r requirements.txt (line 10)) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15->-r requirements.txt (line 10)) (46.1.3)
# Building wheels for collected packages: visdom, torchfile, gast
#   Building wheel for visdom (setup.py) ... done
#   Created wheel for visdom: filename=visdom-0.1.8.9-py3-none-any.whl size=668534 sha256=a4a874637221aaf3706518c90a59b6bfb61a494384c61cebe4eb9da3c027b24b
#   Stored in directory: /root/.cache/pip/wheels/2d/cd/fb/005445070865d4e45365b2946ee88085a7392370f152cf371c
#   Building wheel for torchfile (setup.py) ... done
#   Created wheel for torchfile: filename=torchfile-0.1.0-py3-none-any.whl size=6623 sha256=5034eb6911f897a2b03703ab13a390eaf79df73706368013109fb497961c53f3
#   Stored in directory: /root/.cache/pip/wheels/55/79/ec/084a3a2e348d72852cc0c13c559c923c13ca54db86e699b681
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7635 sha256=5fe40e9e46113e7b399db181fdcdd10f3f9242174e347466dc57158086e1bfe5
#   Stored in directory: /root/.cache/pip/wheels/19/a7/b9/0740c7a3a7d1d348f04823339274b90de25fbcd217b2ee1fbe
# Successfully built visdom torchfile gast
# ERROR: tf-nightly-gpu 2.2.0.dev20200403 has requirement gast==0.3.3, but you'll have gast 0.2.2 which is incompatible.
# ERROR: tf-nightly-gpu 2.2.0.dev20200403 has requirement scipy==1.4.1; python_version >= "3", but you'll have scipy 1.1.0 which is incompatible.
# Installing collected packages: torch, pillow, torchvision, dominate, scipy, jsonpointer, jsonpatch, torchfile, websocket-client, visdom, tqdm, tensorflow-estimator, tensorboard, keras-applications, gast, astor, tensorflow-gpu, cycler, kiwisolver, pyparsing, matplotlib
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: gast
#     Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
# Successfully installed astor-0.8.1 cycler-0.10.0 dominate-2.5.1 gast-0.2.2 jsonpatch-1.25 jsonpointer-2.0 keras-applications-1.0.8 kiwisolver-1.2.0 matplotlib-3.2.1 pillow-7.1.1 pyparsing-2.4.7 scipy-1.1.0 tensorboard-1.15.0 tensorflow-estimator-1.15.1 tensorflow-gpu-1.15.0 torch-1.4.0 torchfile-0.1.0 torchvision-0.5.0 tqdm-4.45.0 visdom-0.1.8.9 websocket-client-0.57.0

# %%
# !python inception_pytorch/calculate_inception_moments.py --dataset C10 --data_root datasets
# Out:
# {'dataset': 'C10', 'data_root': 'datasets', 'batch_size': 64, 'parallel': False, 'augment': False, 'num_workers': 8, 'shuffle': False, 'seed': 0}
# Using dataset root location datasets/cifar10
# Data will not be augmented...
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to datasets/cifar10/cifar-10-python.tar.gz
# 170500096it [00:08, 20145453.03it/s]
# Extracting datasets/cifar10/cifar-10-python.tar.gz to datasets/cifar10
# (50000, 3072)
# Downloading: "https://download.pytorch.org/models/inception_v3_google-1a9a5a14.pth" to /root/.cache/torch/checkpoints/inception_v3_google-1a9a5a14.pth
# 100%|########################################| 104M/104M [00:02<00:00, 36.4MB/s]
# 100%|#########################################| 782/782 [01:44<00:00,  7.50it/s]
# Calculating inception metrics...
# Training data from dataset C10 has IS of 10.20104 +/- 0.13644
# Calculating means and covariances...
# Saving calculated means and covariances to disk...

# %%
# !python train.py --name egan_cifar10 \
       --dataset_mode torchvision --batch_size 32 --eval_size 256 --dataroot None \
       --model egan \
       --gpu_ids 0 \
       --download_root ./datasets/cifar10 --dataset_name CIFAR10 \
       --crop_size 32 --load_size 32 \
       --d_loss_mode vanilla --g_loss_mode nsgan vanilla lsgan --which_D S \
       --lambda_f 0.05 --candi_num 1 --z_type Uniform --z_dim 100 \
       --netD DCGAN_cifar10 --netG DCGAN_cifar10 --ngf 128 --ndf 128 --g_norm none --d_norm batch \
       --init_type normal --init_gain 0.02 \
       --no_dropout --no_flip \
       --D_iters 3 \
       --use_pytorch_scores --score_name IS --evaluation_size 50000 --fid_batch_size 500 \
       --print_freq 130 --display_freq 130 --score_freq 5000 --display_id -1 --save_giters_freq 100000 \
       --total_num_giters 260
# Out:
# WARNING:tensorflow:From /root/Evolutionary-GAN-DL/util/inception.py:77: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# WARNING:tensorflow:From /root/Evolutionary-GAN-DL/util/inception.py:78: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# 2020-04-19 04:18:30.606643: W tensorflow/core/framework/op_def_util.cc:357] Op BatchNormWithGlobalNormalization is deprecated. It will cease to work in GraphDef version 9. Use tf.nn.batch_normalization().
# WARNING:tensorflow:From /root/Evolutionary-GAN-DL/util/inception.py:82: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /root/Evolutionary-GAN-DL/util/inception.py:23: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# 2020-04-19 04:18:30.737617: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2020-04-19 04:18:30.751744: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3500000000 Hz
# 2020-04-19 04:18:30.752403: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x9931d40 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-04-19 04:18:30.752428: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-04-19 04:18:30.754611: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-19 04:18:30.944544: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x99315f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-04-19 04:18:30.944595: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): GeForce GTX 1080 Ti, Compute Capability 6.1
# 2020-04-19 04:18:30.946228: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.6325
# pciBusID: 0000:67:00.0
# 2020-04-19 04:18:30.946403: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcudart.so.10.0'; dlerror: libcudart.so.10.0: cannot open shared object file: No such file or directory
# 2020-04-19 04:18:30.946504: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcublas.so.10.0'; dlerror: libcublas.so.10.0: cannot open shared object file: No such file or directory
# 2020-04-19 04:18:30.946594: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcufft.so.10.0'; dlerror: libcufft.so.10.0: cannot open shared object file: No such file or directory
# 2020-04-19 04:18:30.946682: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcurand.so.10.0'; dlerror: libcurand.so.10.0: cannot open shared object file: No such file or directory
# 2020-04-19 04:18:30.946770: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcusolver.so.10.0'; dlerror: libcusolver.so.10.0: cannot open shared object file: No such file or directory
# 2020-04-19 04:18:30.946858: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcusparse.so.10.0'; dlerror: libcusparse.so.10.0: cannot open shared object file: No such file or directory
# 2020-04-19 04:18:30.954219: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-19 04:18:30.954255: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1641] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2020-04-19 04:18:30.954287: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-04-19 04:18:30.954303: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-04-19 04:18:30.954317: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# ----------------- Options ---------------
#                   D_iters: 3                             	[default: 1]
#                batch_size: 32                            	[default: 1]
#                     beta1: 0.5
#                     beta2: 0.999
#                 candi_num: 1                             	[default: 2]
#                   cat_num: 10
#                      cgan: False
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 32                            	[default: 256]
#               d_loss_mode: vanilla                       	[default: lsgan]
#                    d_norm: batch
#                  dataroot: None                          	[default: None]
#              dataset_mode: torchvision                   	[default: unaligned]
#              dataset_name: CIFAR10
#               display_env: main
#              display_freq: 130                           	[default: 400]
#                display_id: -1                            	[default: 1]
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#             download_root: ./datasets/cifar10            	[default: ./datasets]
#                     epoch: latest
#               epoch_count: 1
#                 eval_size: 256                           	[default: 64]
#           evaluation_size: 50000
#            fid_batch_size: 500                           	[default: 100]
#             fid_stat_file: ./TTUR/stats/fid_stats_cifar10_train.npz
#               g_loss_mode: ['nsgan', 'vanilla', 'lsgan'] 	[default: ['nsgan', 'lsgan', 'vanilla']]
#                    g_norm: none
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: True                          	[default: None]
#                  lambda_f: 0.05                          	[default: 0.1]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 32                            	[default: 256]
#                      lr_d: 0.0002
#            lr_decay_iters: 50
#                      lr_g: 0.0002
#                 lr_policy: linear
#          max_dataset_size: inf
#                     model: egan                          	[default: cycle_gan]
#                n_layers_D: 3
#                      name: egan_cifar10                  	[default: experiment_name]
#                       ndf: 128                           	[default: 64]
#                      netD: DCGAN_cifar10                 	[default: basic]
#                      netG: DCGAN_cifar10                 	[default: resnet_9blocks]
#                       ngf: 128                           	[default: 64]
#                     niter: 100
#               niter_decay: 100
#                no_dropout: True                          	[default: False]
#                   no_flip: True                          	[default: False]
#                   no_html: False
#               num_threads: 4
#                 output_nc: 3
#                     phase: train
#                 pool_size: 50
#                preprocess: resize_and_crop
#                print_freq: 130                           	[default: 100]
#              save_by_iter: False
#          save_giters_freq: 100000                        	[default: 10000]
#          save_latest_freq: 5000
#                score_freq: 5000                          	[default: 100]
#                score_name: ['IS']                        	[default: ['FID', 'IS']]
#            serial_batches: False
#                    suffix:
#          total_num_giters: 260                           	[default: 500000]
#          update_html_freq: 1001
#                    use_gp: False
#        use_pytorch_scores: True                          	[default: False]
#                   verbose: False
#                   which_D: S
#                     z_dim: 100                           	[default: 128]
#                    z_type: Uniform                       	[default: Gaussian]
# ----------------- End -------------------
# Files already downloaded and verified
# dataset [TorchvisionDataset] was created
# The number of training images = 50000
# initialize network with normal
# initialize network with normal
# model [EGANModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 12.654 M
# [Network D] Total number of parameters : 11.033 M
# -----------------------------------------------
# create web directory ./checkpoints/egan_cifar10/web...
# Figure(640x480)
# Figure(640x480)
# (epoch_1) End of giters 130 / 260 	 Time Taken: 130 sec
# Figure(640x480)
# Figure(640x480)
# (epoch_2) End of giters 260 / 260 	 Time Taken: 128 sec
# epoch_list [0, 1]
# losses_D [0.002876988146454096, 0.0026174928061664104]
# losses_G [74.6818618774414, 90.08999633789062]
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
