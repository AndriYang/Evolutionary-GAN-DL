# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: torchvision>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 2)) (0.5.0)
# Requirement already satisfied: dominate>=2.3.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 3)) (2.5.1)
# Requirement already satisfied: visdom>=0.1.8.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 4)) (0.1.8.9)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 5)) (1.18.2)
# Requirement already satisfied: h5py>=2.7.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 6)) (2.10.0)
# Requirement already satisfied: pillow>=3.1.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 7)) (7.1.1)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 8)) (4.45.0)
# Requirement already satisfied: scipy==1.1.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 9)) (1.1.0)
# Requirement already satisfied: tensorflow-gpu==1.15 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 10)) (1.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision>=0.2.1->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from visdom>=0.1.8.3->-r requirements.txt (line 4)) (2.23.0)
# Requirement already satisfied: tornado in /usr/local/lib/python3.6/dist-packages (from visdom>=0.1.8.3->-r requirements.txt (line 4)) (6.0.4)
# Requirement already satisfied: torchfile in /usr/local/lib/python3.6/dist-packages (from visdom>=0.1.8.3->-r requirements.txt (line 4)) (0.1.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.6/dist-packages (from visdom>=0.1.8.3->-r requirements.txt (line 4)) (0.57.0)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.6/dist-packages (from visdom>=0.1.8.3->-r requirements.txt (line 4)) (19.0.0)
# Requirement already satisfied: jsonpatch in /usr/local/lib/python3.6/dist-packages (from visdom>=0.1.8.3->-r requirements.txt (line 4)) (1.25)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15->-r requirements.txt (line 10)) (0.8.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15->-r requirements.txt (line 10)) (1.1.0)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15->-r requirements.txt (line 10)) (0.2.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15->-r requirements.txt (line 10)) (3.2.0)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15->-r requirements.txt (line 10)) (1.15.0)
# Requirement already satisfied: wheel>=0.26 in /usr/lib/python3/dist-packages (from tensorflow-gpu==1.15->-r requirements.txt (line 10)) (0.30.0)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15->-r requirements.txt (line 10)) (1.15.1)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15->-r requirements.txt (line 10)) (1.0.8)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15->-r requirements.txt (line 10)) (1.27.2)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15->-r requirements.txt (line 10)) (1.1.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15->-r requirements.txt (line 10)) (0.9.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15->-r requirements.txt (line 10)) (0.2.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15->-r requirements.txt (line 10)) (3.11.3)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15->-r requirements.txt (line 10)) (1.12.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->visdom>=0.1.8.3->-r requirements.txt (line 4)) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->visdom>=0.1.8.3->-r requirements.txt (line 4)) (1.25.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/lib/python3/dist-packages (from requests->visdom>=0.1.8.3->-r requirements.txt (line 4)) (2.6)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->visdom>=0.1.8.3->-r requirements.txt (line 4)) (3.0.4)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.6/dist-packages (from jsonpatch->visdom>=0.1.8.3->-r requirements.txt (line 4)) (2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15->-r requirements.txt (line 10)) (3.2.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15->-r requirements.txt (line 10)) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15->-r requirements.txt (line 10)) (46.1.3)

# %%
# !python inception_pytorch/calculate_inception_moments.py --dataset C10 --data_root datasets
# Out:
# {'dataset': 'C10', 'data_root': 'datasets', 'batch_size': 64, 'parallel': False, 'augment': False, 'num_workers': 8, 'shuffle': False, 'seed': 0}
# Using dataset root location datasets/cifar10
# Data will not be augmented...
# Files already downloaded and verified
# (50000, 3072)
# 100%|#########################################| 782/782 [01:42<00:00,  7.66it/s]
# Calculating inception metrics...
# Training data from dataset C10 has IS of 10.20104 +/- 0.13644
# Calculating means and covariances...
# Saving calculated means and covariances to disk...

# %%
# !python train.py --name egan_cifar10 \
       --dataset_mode torchvision --batch_size 32 --eval_size 256 --dataroot None \
       --model egan \
       --gpu_ids 0 \
       --download_root ./datasets/cifar10 --dataset_name CIFAR10 \
       --crop_size 32 --load_size 32 \
       --d_loss_mode vanilla --g_loss_mode nsgan vanilla lsgan --which_D S \
       --lambda_f 0.05 --candi_num 1 --z_type Uniform --z_dim 100 \
       --netD DCGAN_cifar10 --netG DCGAN_cifar10 --ngf 128 --ndf 128 --g_norm none --d_norm batch \
       --init_type normal --init_gain 0.02 \
       --no_dropout --no_flip \
       --D_iters 3 \
       --use_pytorch_scores --score_name IS --evaluation_size 50000 --fid_batch_size 500 \
       --print_freq 130 --display_freq 130 --score_freq 5000 --display_id -1 --save_giters_freq 100000 \
       --total_num_giters 10000
# Out:
# WARNING:tensorflow:From /root/Evolutionary-GAN-DL/util/inception.py:77: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# WARNING:tensorflow:From /root/Evolutionary-GAN-DL/util/inception.py:78: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# 2020-04-18 15:37:22.025242: W tensorflow/core/framework/op_def_util.cc:357] Op BatchNormWithGlobalNormalization is deprecated. It will cease to work in GraphDef version 9. Use tf.nn.batch_normalization().
# WARNING:tensorflow:From /root/Evolutionary-GAN-DL/util/inception.py:82: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /root/Evolutionary-GAN-DL/util/inception.py:23: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# 2020-04-18 15:37:22.202209: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-04-18 15:37:22.279852: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 4200000000 Hz
# 2020-04-18 15:37:22.280167: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x96e4d40 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-04-18 15:37:22.280184: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-04-18 15:37:22.282558: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-18 15:37:22.673924: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-18 15:37:22.674825: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x96e45f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-04-18 15:37:22.674864: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): GeForce GTX 1080 Ti, Compute Capability 6.1
# 2020-04-18 15:37:22.675067: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-18 15:37:22.675826: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.6705
# pciBusID: 0000:03:00.0
# 2020-04-18 15:37:22.675980: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcudart.so.10.0'; dlerror: libcudart.so.10.0: cannot open shared object file: No such file or directory
# 2020-04-18 15:37:22.676054: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcublas.so.10.0'; dlerror: libcublas.so.10.0: cannot open shared object file: No such file or directory
# 2020-04-18 15:37:22.676108: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcufft.so.10.0'; dlerror: libcufft.so.10.0: cannot open shared object file: No such file or directory
# 2020-04-18 15:37:22.676157: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcurand.so.10.0'; dlerror: libcurand.so.10.0: cannot open shared object file: No such file or directory
# 2020-04-18 15:37:22.676208: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcusolver.so.10.0'; dlerror: libcusolver.so.10.0: cannot open shared object file: No such file or directory
# 2020-04-18 15:37:22.676258: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcusparse.so.10.0'; dlerror: libcusparse.so.10.0: cannot open shared object file: No such file or directory
# 2020-04-18 15:37:22.679818: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-04-18 15:37:22.679876: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1641] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2020-04-18 15:37:22.679923: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-04-18 15:37:22.679938: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-04-18 15:37:22.679950: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# ----------------- Options ---------------
#                   D_iters: 3                             	[default: 1]
#                batch_size: 32                            	[default: 1]
#                     beta1: 0.5
#                     beta2: 0.999
#                 candi_num: 1                             	[default: 2]
#                   cat_num: 10
#                      cgan: False
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 32                            	[default: 256]
#               d_loss_mode: vanilla                       	[default: lsgan]
#                    d_norm: batch
#                  dataroot: None                          	[default: None]
#              dataset_mode: torchvision                   	[default: unaligned]
#              dataset_name: CIFAR10
#               display_env: main
#              display_freq: 200                           	[default: 400]
#                display_id: -1                            	[default: 1]
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#             download_root: ./datasets/cifar10            	[default: ./datasets]
#                     epoch: latest
#               epoch_count: 1
#                 eval_size: 256                           	[default: 64]
#           evaluation_size: 50000
#            fid_batch_size: 500                           	[default: 100]
#             fid_stat_file: ./TTUR/stats/fid_stats_cifar10_train.npz
#               g_loss_mode: ['nsgan', 'vanilla', 'lsgan'] 	[default: ['nsgan', 'lsgan', 'vanilla']]
#                    g_norm: none
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: True                          	[default: None]
#                  lambda_f: 0.05                          	[default: 0.1]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 32                            	[default: 256]
#                      lr_d: 0.0002
#            lr_decay_iters: 50
#                      lr_g: 0.0002
#                 lr_policy: linear
#          max_dataset_size: inf
#                     model: egan                          	[default: cycle_gan]
#                n_layers_D: 3
#                      name: egan_cifar10                  	[default: experiment_name]
#                       ndf: 128                           	[default: 64]
#                      netD: DCGAN_cifar10                 	[default: basic]
#                      netG: DCGAN_cifar10                 	[default: resnet_9blocks]
#                       ngf: 128                           	[default: 64]
#                     niter: 100
#               niter_decay: 100
#                no_dropout: True                          	[default: False]
#                   no_flip: True                          	[default: False]
#                   no_html: False
#               num_threads: 4
#                 output_nc: 3
#                     phase: train
#                 pool_size: 50
#                preprocess: resize_and_crop
#                print_freq: 200                           	[default: 100]
#              save_by_iter: False
#          save_giters_freq: 100000                        	[default: 10000]
#          save_latest_freq: 5000
#                score_freq: 200                           	[default: 100]
#                score_name: ['IS']                        	[default: ['FID', 'IS']]
#            serial_batches: False
#                    suffix:
#          total_num_giters: 200                           	[default: 500000]
#          update_html_freq: 1001
#                    use_gp: False
#        use_pytorch_scores: True                          	[default: False]
#                   verbose: False
#                   which_D: S
#                     z_dim: 100                           	[default: 128]
#                    z_type: Uniform                       	[default: Gaussian]
# ----------------- End -------------------
# Files already downloaded and verified
# dataset [TorchvisionDataset] was created
# The number of training images = 50000
# initialize network with normal
# initialize network with normal
# model [EGANModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 12.654 M
# [Network D] Total number of parameters : 11.033 M
# -----------------------------------------------
# create web directory ./checkpoints/egan_cifar10/web...
# (epoch_1) End of giters 130 / 200 	 Time Taken: 128 sec
# (epoch: 1, giters: 200, time: 0.039, data: 0.411) G_real: 0.000 G_fake: 82.284 D_real: 0.001 D_fake: 0.000 D_gp: 0.000 G: 82.284 D: 0.001
# generate fid sample batch 1/100
# generate fid sample batch 2/100
# generate fid sample batch 3/100
# generate fid sample batch 4/100
# generate fid sample batch 5/100
# generate fid sample batch 6/100
# generate fid sample batch 7/100
# generate fid sample batch 8/100
# generate fid sample batch 9/100
# generate fid sample batch 10/100
# generate fid sample batch 11/100
# generate fid sample batch 12/100
# generate fid sample batch 13/100
# generate fid sample batch 14/100
# generate fid sample batch 15/100
# generate fid sample batch 16/100
# generate fid sample batch 17/100
# generate fid sample batch 18/100
# generate fid sample batch 19/100
# generate fid sample batch 20/100
# generate fid sample batch 21/100
# generate fid sample batch 22/100
# generate fid sample batch 23/100
# generate fid sample batch 24/100
# generate fid sample batch 25/100
# generate fid sample batch 26/100
# generate fid sample batch 27/100
# generate fid sample batch 28/100
# generate fid sample batch 29/100
# generate fid sample batch 30/100
# generate fid sample batch 31/100
# generate fid sample batch 32/100
# generate fid sample batch 33/100
# generate fid sample batch 34/100
# generate fid sample batch 35/100
# generate fid sample batch 36/100
# generate fid sample batch 37/100
# generate fid sample batch 38/100
# generate fid sample batch 39/100
# generate fid sample batch 40/100
# generate fid sample batch 41/100
# generate fid sample batch 42/100
# generate fid sample batch 43/100
# generate fid sample batch 44/100
# generate fid sample batch 45/100
# generate fid sample batch 46/100
# generate fid sample batch 47/100
# generate fid sample batch 48/100
# generate fid sample batch 49/100
# generate fid sample batch 50/100
# generate fid sample batch 51/100
# generate fid sample batch 52/100
# generate fid sample batch 53/100
# generate fid sample batch 54/100
# generate fid sample batch 55/100
# generate fid sample batch 56/100
# generate fid sample batch 57/100
# generate fid sample batch 58/100
# generate fid sample batch 59/100
# generate fid sample batch 60/100
# generate fid sample batch 61/100
# generate fid sample batch 62/100
# generate fid sample batch 63/100
# generate fid sample batch 64/100
# generate fid sample batch 65/100
# generate fid sample batch 66/100
# generate fid sample batch 67/100
# generate fid sample batch 68/100
# generate fid sample batch 69/100
# generate fid sample batch 70/100
# generate fid sample batch 71/100
# generate fid sample batch 72/100
# generate fid sample batch 73/100
# generate fid sample batch 74/100
# generate fid sample batch 75/100
# generate fid sample batch 76/100
# generate fid sample batch 77/100
# generate fid sample batch 78/100
# generate fid sample batch 79/100
# generate fid sample batch 80/100
# generate fid sample batch 81/100
# generate fid sample batch 82/100
# generate fid sample batch 83/100
# generate fid sample batch 84/100
# generate fid sample batch 85/100
# generate fid sample batch 86/100
# generate fid sample batch 87/100
# generate fid sample batch 88/100
# generate fid sample batch 89/100
# generate fid sample batch 90/100
# generate fid sample batch 91/100
# generate fid sample batch 92/100
# generate fid sample batch 93/100
# generate fid sample batch 94/100
# generate fid sample batch 95/100
# generate fid sample batch 96/100
# generate fid sample batch 97/100
# generate fid sample batch 98/100
# generate fid sample batch 99/100
# generate fid sample batch 100/100
# 50000 samples generating done
# Gathering activations...
# Calculating Inception Score...
# 1.0144295 9.13774e-05
# (epoch: 1, giters: 200) IS_mean: 1.014 IS_var: 0.000
# (epoch_2) End of giters 260 / 200 	 Time Taken: 236 sec
